# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
# 1.Problemin Çözümünü Buraya Yazınız

import time

def vki_hesaplama(kilo. boy):
    vki=kilo/(boy**2)
    return round(vki,1)

def deger_aralığı(vki):
    if vki< 18.5:
        return "zayıf"
    elif vki <= 24.9:
        return "normal kilolu"
    elif vki <=29.9:
        return "fazla kilolu"
    elif vki <= 39.9:
        return "obez"
    elif vki >= 40:
        return "ileri obez"

def cikti_olustur(isim,yas,kilo,boy,vki,değer):
    kayit_tarih= time.ctime(time.time())
    t1 = f"kullanıcı adı {isim}\n"
    t2=f"kullanıcının yas, kilo, boy bilgisi {yas},{kilo},{boy}\n"
    t3=f"kullanıcın vücut kütle indeksi{vki}\n"
    t4=f"değer arlığı {değer}\n"
    t5=f"oluşturma tarihi {kayit_tarih}\n"
    output= ta+t2+t3+t4+t5
    return output


def main():
        giris_sayısı= int(input("kaç kullanıcı verisi gireceksiniz"))
        for i in range(giris_sayısı):
            print(f"kullanıcı adı {i+1}")
            isim=input("isim gitiniz: ")
            yas= int(input("yas: "))
            kilo= float(input("kilo: "))
            boy= float(input("boy: "))
            vki=vki_hesaplama(boy,kilo)
            deger=deger_aralığı(vki)
            output= cikti_olustur(isim,yas,kilo,boy,vki,deger)

            with open ("saglık.txt", "a") as f:
                f.write(output)
                f.write("*"*20)
                f.write("\n")
                print("kullanıcı kaydedildi: ")

        print("veriler saglık.txt dosyasına kaydedildi.\n")
main()

# %%
# 2.Problemin Çözümünü Buraya Yazınız
import time 

menu={
    "elma":0.50,
    "armut":0.75,
    "üzüm":2.,
    "çilek":1.75,
    "muz:":2.,
    "kavun":2.15,
    "karpuz":1.99,

}

print("elmanın fiyatı: ", menu["elma"])
print("kavunun fiyatı: ", menu["kavun"])


def display_menu():
    print("----------denbar menü-----------")
    for item in list(menu.keys):
        print(f"{item.upper():<10} : {menu[item]} tl")

def tek_urun_fıyat_hesaplama(urun, adet):
    assert adet >= 0 , "ürün adedi0 ve 0 dan küçük olamaz."
    if urun not in list(menu.keys()):
        return None
    else:
        return menu[urun] * adet
    
def satin_alma():
    display_menu()
    print("lütfen almak istediğiniz ürünürü giriniz . çıkıs yapmak için 0 nasınız")
    satin_alinan_urunler=[]
    satin_alma_adedi=[]
    son_fiyat= 0
    

    while 1:
        eklenecek_urun=input("hangi ürünü istiyorsunuz")
        if eklenecek_urun == "0":
            print("fiş kaydediliyor: ")
            break

        ekleme_adedi= int(input("kaç adet eklemek isitoyrunuz:"))
        fiyat=tek_urun_fıyat_hesaplama(eklenecek_urun,ekleme_adedi)
        if fiyat is None:
            print("yanlış giriş yaptınız ürün eklenmedi: ")

        else:
            print(f"satın alma ücreti: {fiyat}.\n")
            checek= input("satın almayı onaylıyor musunuz?")
            if checek == "y":
                print("satın alım onaylandı. ")
                print("-"*40)
                son_fiyat += fiyat
                satin_alinan_urunler.append(eklenecek_urun)
                satin_alma_adedi.append(ekleme_adedi)
                print(f"ara toplam: {son_fiyat}")

            elif checek == "n":
                print("satın alma işlemi iptal edildi.")
                print("-"*40)
    return son_fiyat,satin_alinan_urunler,satin_alma_adedi



def main():
    print("denbar")
